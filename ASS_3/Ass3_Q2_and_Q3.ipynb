# %%
# !pip install -q tensorflow seaborn scikit-learn matplotlib tqdm pandas

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.applications import VGG16
from tensorflow.keras.utils import to_categorical
import numpy as np, matplotlib.pyplot as plt, seaborn as sns, pandas as pd
from sklearn.metrics import confusion_matrix, roc_curve, auc, classification_report
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import warnings
warnings.filterwarnings("ignore")

# %%
print("TensorFlow:", tf.__version__)
print("GPU:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow: 2.19.0
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
def plot_history(history, title):
    plt.figure(figsize=(10,4))
    plt.subplot(1,2,1)
    plt.plot(history.history['accuracy'], label='train')
    plt.plot(history.history['val_accuracy'], label='val')
    plt.title(title+" Accuracy"); plt.legend()
    plt.subplot(1,2,2)
    plt.plot(history.history['loss'], label='train')
    plt.plot(history.history['val_loss'], label='val')
    plt.title(title+" Loss"); plt.legend()
    plt.show()

def plot_cm(y_true, y_pred, title):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(6,5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title(title); plt.xlabel('Predicted'); plt.ylabel('Actual')
    plt.show()

def plot_roc(y_true_onehot, y_pred_prob, title):
    plt.figure(figsize=(6,5))
    for i in range(y_true_onehot.shape[1]):
        fpr, tpr, _ = roc_curve(y_true_onehot[:,i], y_pred_prob[:,i])
        plt.plot(fpr, tpr, label=f'Class {i}')
    plt.plot([0,1],[0,1],'k--')
    plt.title(f"{title} ROC Curve")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.legend()
    plt.show()

def macro_auc(y_true_onehot, y_pred_prob):
    fpr,tpr,roc_auc={},{},{}
    for i in range(y_true_onehot.shape[1]):
        fpr[i],tpr[i],_ = roc_curve(y_true_onehot[:,i], y_pred_prob[:,i])
        roc_auc[i]=auc(fpr[i],tpr[i])
    return np.mean(list(roc_auc.values()))

# %%
(m_x_train, m_y_train),(m_x_test, m_y_test)=keras.datasets.mnist.load_data()
m_x_all = np.concatenate([m_x_train, m_x_test]).astype('float32')/255.0
m_x_all = np.expand_dims(m_x_all,-1)
m_y_all = np.concatenate([m_y_train, m_y_test])
m_y_all_cat = to_categorical(m_y_all,10)
m_x_all_vgg = tf.image.resize(tf.image.grayscale_to_rgb(tf.convert_to_tensor(m_x_all)),[32,32]).numpy()

# CIFAR-10
(c_x_train,c_y_train),(c_x_test,c_y_test)=keras.datasets.cifar10.load_data()
c_x_all = np.concatenate([c_x_train,c_x_test]).astype('float32')/255.0
c_y_all = np.concatenate([c_y_train,c_y_test]).flatten()
c_y_all_cat = to_categorical(c_y_all,10)

# %%
def build_cnn(input_shape,n_classes):
    model=models.Sequential([
        layers.Conv2D(32,3,activation='relu',padding='same',input_shape=input_shape),
        layers.Conv2D(32,3,activation='relu',padding='same'),
        layers.MaxPooling2D(),
        layers.Conv2D(64,3,activation='relu',padding='same'),
        layers.MaxPooling2D(),
        layers.Flatten(),
        layers.Dense(128,activation='relu'),
        layers.Dense(n_classes,activation='softmax')
    ])
    model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
    return model

def build_vgg16(input_shape,n_classes):
    base=VGG16(include_top=False,weights=None,input_shape=input_shape)
    x=layers.Flatten()(base.output)
    x=layers.Dense(256,activation='relu')(x)
    out=layers.Dense(n_classes,activation='softmax')(x)
    model=models.Model(base.input,out)
    model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
    return model

def build_alexnet_small(input_shape,n_classes):
    model=models.Sequential([
        layers.Conv2D(64,(3,3),activation='relu',padding='same',input_shape=input_shape),
        layers.MaxPooling2D((2,2)),
        layers.Conv2D(128,(3,3),activation='relu',padding='same'),
        layers.MaxPooling2D((2,2)),
        layers.Conv2D(256,(3,3),activation='relu',padding='same'),
        layers.MaxPooling2D((2,2)),
        layers.Flatten(),
        layers.Dense(512,activation='relu'),
        layers.Dense(n_classes,activation='softmax')
    ])
    model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
    return model

def build_googlenet_small(input_shape,n_classes):
    inp=layers.Input(shape=input_shape)
    x=layers.Conv2D(64,3,activation='relu',padding='same')(inp)
    x=layers.Conv2D(128,3,activation='relu',padding='same')(x)
    x=layers.MaxPooling2D(2)(x)
    x=layers.Conv2D(256,3,activation='relu',padding='same')(x)
    x=layers.MaxPooling2D(2)(x)
    x=layers.Flatten()(x)
    x=layers.Dense(512,activation='relu')(x)
    out=layers.Dense(n_classes,activation='softmax')(x)
    model=models.Model(inp,out)
    model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
    return model

def build_rnn(input_shape,n_classes):
    model=models.Sequential([
        layers.Input(shape=(input_shape[0],input_shape[1])),
        layers.LSTM(128),
        layers.Dense(128,activation='relu'),
        layers.Dense(n_classes,activation='softmax')
    ])
    model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
    return model

# %%
def train_and_eval(model,X_train,y_train,X_test,y_test,y_test_cat,name,dataset,split_ratio):
    hist=model.fit(X_train,y_train,validation_split=0.1,epochs=5,batch_size=128,verbose=2)
    eval_res=model.evaluate(X_test,y_test_cat,verbose=0)
    preds=model.predict(X_test)
    pred_labels=np.argmax(preds,axis=1)
    rocA=macro_auc(y_test_cat,preds)
    report=classification_report(y_test,pred_labels,output_dict=True,zero_division=0)
    acc,prec,rec,f1=eval_res[1],report['weighted avg']['precision'],report['weighted avg']['recall'],report['weighted avg']['f1-score']
    return {"Dataset":dataset,"Model":name,"Split":split_ratio,"Accuracy":acc,"Precision":prec,"Recall":rec,"F1":f1,"AUC":rocA,"History":hist,"Y_true":y_test,"Y_pred":preds}

# %%
results=[]
splits = [0.6,0.7,0.8]

# %%
mnist_models=[
    ("CNN", build_cnn((28,28,1),10)),
    ("VGG16", build_vgg16((32,32,3),10)),
    ("AlexNet", build_alexnet_small((32,32,3),10)),
    ("GoogLeNet", build_googlenet_small((32,32,3),10)),
    ("RNN", build_rnn((28,28),10))
]

for split in splits:
    X_train, X_test, y_train, y_test = train_test_split(m_x_all, m_y_all, train_size=split, random_state=42, stratify=m_y_all)
    X_train_cat, X_test_cat = to_categorical(y_train,10), to_categorical(y_test,10)
    X_train_vgg, X_test_vgg = tf.image.resize(tf.image.grayscale_to_rgb(tf.convert_to_tensor(X_train)),[32,32]).numpy(), \
                               tf.image.resize(tf.image.grayscale_to_rgb(tf.convert_to_tensor(X_test)),[32,32]).numpy()

    for name, model in mnist_models:
        if name in ["VGG16","AlexNet","GoogLeNet"]:
            res=train_and_eval(model,X_train_vgg,X_train_cat,X_test_vgg,y_test,X_test_cat,name,"MNIST",split)
        elif name=="RNN":
            res=train_and_eval(model,X_train[:,:,0],X_train_cat,X_test[:,:,0],y_test,X_test_cat,name,"MNIST",split)
        else:
            res=train_and_eval(model,X_train,X_train_cat,X_test,y_test,X_test_cat,name,"MNIST",split)
        results.append(res)
# Out:
# Epoch 1/5
# 296/296 - 15s - 49ms/step - accuracy: 0.9311 - loss: 0.2334 - val_accuracy: 0.9743 - val_loss: 0.0775
# Epoch 2/5
# 296/296 - 3s - 9ms/step - accuracy: 0.9820 - loss: 0.0573 - val_accuracy: 0.9829 - val_loss: 0.0553
# Epoch 3/5
# 296/296 - 2s - 7ms/step - accuracy: 0.9880 - loss: 0.0367 - val_accuracy: 0.9874 - val_loss: 0.0488
# Epoch 4/5
# 296/296 - 2s - 7ms/step - accuracy: 0.9912 - loss: 0.0276 - val_accuracy: 0.9867 - val_loss: 0.0413
# Epoch 5/5
# 296/296 - 2s - 7ms/step - accuracy: 0.9937 - loss: 0.0192 - val_accuracy: 0.9874 - val_loss: 0.0466
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# Epoch 1/5
# 296/296 - 34s - 116ms/step - accuracy: 0.1118 - loss: 2.3045 - val_accuracy: 0.1126 - val_loss: 2.3014
# Epoch 2/5
# 296/296 - 22s - 75ms/step - accuracy: 0.1125 - loss: 2.3014 - val_accuracy: 0.1126 - val_loss: 2.3013
# Epoch 3/5
# 296/296 - 22s - 74ms/step - accuracy: 0.1125 - loss: 2.3013 - val_accuracy: 0.1126 - val_loss: 2.3014
# Epoch 4/5
# 296/296 - 22s - 76ms/step - accuracy: 0.1125 - loss: 2.3014 - val_accuracy: 0.1126 - val_loss: 2.3013
# Epoch 5/5
# 296/296 - 22s - 74ms/step - accuracy: 0.1125 - loss: 2.3013 - val_accuracy: 0.1126 - val_loss: 2.3013
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step
# Epoch 1/5
# 296/296 - 9s - 30ms/step - accuracy: 0.9449 - loss: 0.1761 - val_accuracy: 0.9795 - val_loss: 0.0663
# Epoch 2/5
# 296/296 - 4s - 12ms/step - accuracy: 0.9858 - loss: 0.0464 - val_accuracy: 0.9898 - val_loss: 0.0332
# Epoch 3/5
# 296/296 - 3s - 11ms/step - accuracy: 0.9906 - loss: 0.0293 - val_accuracy: 0.9905 - val_loss: 0.0355
# Epoch 4/5
# 296/296 - 3s - 11ms/step - accuracy: 0.9937 - loss: 0.0199 - val_accuracy: 0.9907 - val_loss: 0.0299
# Epoch 5/5
# 296/296 - 4s - 12ms/step - accuracy: 0.9950 - loss: 0.0154 - val_accuracy: 0.9888 - val_loss: 0.0408
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# Epoch 1/5
# 296/296 - 14s - 48ms/step - accuracy: 0.9547 - loss: 0.1388 - val_accuracy: 0.9838 - val_loss: 0.0503
# Epoch 2/5
# 296/296 - 8s - 28ms/step - accuracy: 0.9880 - loss: 0.0382 - val_accuracy: 0.9881 - val_loss: 0.0390
# Epoch 3/5
# 296/296 - 8s - 28ms/step - accuracy: 0.9925 - loss: 0.0235 - val_accuracy: 0.9864 - val_loss: 0.0468
# Epoch 4/5
# 296/296 - 8s - 29ms/step - accuracy: 0.9939 - loss: 0.0185 - val_accuracy: 0.9893 - val_loss: 0.0347
# Epoch 5/5
# 296/296 - 8s - 28ms/step - accuracy: 0.9958 - loss: 0.0134 - val_accuracy: 0.9881 - val_loss: 0.0409
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step
# Epoch 1/5
# 296/296 - 3s - 11ms/step - accuracy: 0.1112 - loss: 2.3018 - val_accuracy: 0.1126 - val_loss: 2.3018
# Epoch 2/5
# 296/296 - 2s - 6ms/step - accuracy: 0.1125 - loss: 2.3015 - val_accuracy: 0.1126 - val_loss: 2.3014
# Epoch 3/5
# 296/296 - 2s - 8ms/step - accuracy: 0.1125 - loss: 2.3014 - val_accuracy: 0.1126 - val_loss: 2.3016
# Epoch 4/5
# 296/296 - 2s - 7ms/step - accuracy: 0.1125 - loss: 2.3014 - val_accuracy: 0.1126 - val_loss: 2.3014
# Epoch 5/5
# 296/296 - 2s - 6ms/step - accuracy: 0.1125 - loss: 2.3014 - val_accuracy: 0.1126 - val_loss: 2.3015
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# Epoch 1/5
# 345/345 - 4s - 12ms/step - accuracy: 0.9924 - loss: 0.0238 - val_accuracy: 0.9949 - val_loss: 0.0144
# Epoch 2/5
# 345/345 - 2s - 7ms/step - accuracy: 0.9959 - loss: 0.0134 - val_accuracy: 0.9949 - val_loss: 0.0173
# Epoch 3/5
# 345/345 - 2s - 7ms/step - accuracy: 0.9968 - loss: 0.0096 - val_accuracy: 0.9945 - val_loss: 0.0194
# Epoch 4/5
# 345/345 - 2s - 7ms/step - accuracy: 0.9972 - loss: 0.0083 - val_accuracy: 0.9910 - val_loss: 0.0259
# Epoch 5/5
# 345/345 - 3s - 8ms/step - accuracy: 0.9975 - loss: 0.0073 - val_accuracy: 0.9929 - val_loss: 0.0213
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/5
# 345/345 - 30s - 86ms/step - accuracy: 0.1124 - loss: 2.3014 - val_accuracy: 0.1133 - val_loss: 2.3008
# Epoch 2/5
# 345/345 - 25s - 74ms/step - accuracy: 0.1124 - loss: 2.3014 - val_accuracy: 0.1133 - val_loss: 2.3008
# Epoch 3/5
# 345/345 - 25s - 73ms/step - accuracy: 0.1124 - loss: 2.3014 - val_accuracy: 0.1133 - val_loss: 2.3008
# Epoch 4/5
# 345/345 - 25s - 73ms/step - accuracy: 0.1124 - loss: 2.3014 - val_accuracy: 0.1133 - val_loss: 2.3010
# Epoch 5/5
# 345/345 - 25s - 74ms/step - accuracy: 0.1124 - loss: 2.3013 - val_accuracy: 0.1133 - val_loss: 2.3008
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Epoch 1/5
# 345/345 - 6s - 18ms/step - accuracy: 0.9933 - loss: 0.0209 - val_accuracy: 0.9965 - val_loss: 0.0114
# Epoch 2/5
# 345/345 - 4s - 12ms/step - accuracy: 0.9956 - loss: 0.0118 - val_accuracy: 0.9951 - val_loss: 0.0143
# Epoch 3/5
# 345/345 - 4s - 11ms/step - accuracy: 0.9966 - loss: 0.0106 - val_accuracy: 0.9941 - val_loss: 0.0175
# Epoch 4/5
# 345/345 - 4s - 12ms/step - accuracy: 0.9977 - loss: 0.0073 - val_accuracy: 0.9953 - val_loss: 0.0149
# Epoch 5/5
# 345/345 - 4s - 12ms/step - accuracy: 0.9974 - loss: 0.0072 - val_accuracy: 0.9941 - val_loss: 0.0166
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# Epoch 1/5
# 345/345 - 12s - 33ms/step - accuracy: 0.9949 - loss: 0.0173 - val_accuracy: 0.9959 - val_loss: 0.0121
# Epoch 2/5
# 345/345 - 10s - 28ms/step - accuracy: 0.9972 - loss: 0.0084 - val_accuracy: 0.9951 - val_loss: 0.0170
# Epoch 3/5
# 345/345 - 10s - 28ms/step - accuracy: 0.9969 - loss: 0.0091 - val_accuracy: 0.9945 - val_loss: 0.0161
# Epoch 4/5
# 345/345 - 10s - 28ms/step - accuracy: 0.9977 - loss: 0.0073 - val_accuracy: 0.9967 - val_loss: 0.0114
# Epoch 5/5
# 345/345 - 10s - 28ms/step - accuracy: 0.9974 - loss: 0.0075 - val_accuracy: 0.9951 - val_loss: 0.0131
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# Epoch 1/5
# 345/345 - 2s - 6ms/step - accuracy: 0.1124 - loss: 2.3014 - val_accuracy: 0.1133 - val_loss: 2.3007
# Epoch 2/5
# 345/345 - 2s - 6ms/step - accuracy: 0.1124 - loss: 2.3014 - val_accuracy: 0.1133 - val_loss: 2.3007
# Epoch 3/5
# 345/345 - 3s - 8ms/step - accuracy: 0.1124 - loss: 2.3014 - val_accuracy: 0.1133 - val_loss: 2.3011
# Epoch 4/5
# 345/345 - 2s - 6ms/step - accuracy: 0.1124 - loss: 2.3014 - val_accuracy: 0.1133 - val_loss: 2.3010
# Epoch 5/5
# 345/345 - 2s - 6ms/step - accuracy: 0.1124 - loss: 2.3014 - val_accuracy: 0.1133 - val_loss: 2.3009
# 657/657 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# Epoch 1/5
# 394/394 - 5s - 11ms/step - accuracy: 0.9954 - loss: 0.0153 - val_accuracy: 0.9941 - val_loss: 0.0193
# Epoch 2/5
# 394/394 - 3s - 7ms/step - accuracy: 0.9973 - loss: 0.0088 - val_accuracy: 0.9961 - val_loss: 0.0153
# Epoch 3/5
# 394/394 - 3s - 7ms/step - accuracy: 0.9985 - loss: 0.0049 - val_accuracy: 0.9937 - val_loss: 0.0200
# Epoch 4/5
# 394/394 - 3s - 8ms/step - accuracy: 0.9984 - loss: 0.0050 - val_accuracy: 0.9946 - val_loss: 0.0173
# Epoch 5/5
# 394/394 - 3s - 7ms/step - accuracy: 0.9976 - loss: 0.0067 - val_accuracy: 0.9911 - val_loss: 0.0326
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/5
# 394/394 - 34s - 85ms/step - accuracy: 0.1129 - loss: 2.3012 - val_accuracy: 0.1093 - val_loss: 2.3022
# Epoch 2/5
# 394/394 - 29s - 73ms/step - accuracy: 0.1129 - loss: 2.3012 - val_accuracy: 0.1093 - val_loss: 2.3019
# Epoch 3/5
# 394/394 - 29s - 75ms/step - accuracy: 0.1129 - loss: 2.3012 - val_accuracy: 0.1093 - val_loss: 2.3023
# Epoch 4/5
# 394/394 - 29s - 74ms/step - accuracy: 0.1129 - loss: 2.3012 - val_accuracy: 0.1093 - val_loss: 2.3021
# Epoch 5/5
# 394/394 - 29s - 74ms/step - accuracy: 0.1129 - loss: 2.3012 - val_accuracy: 0.1093 - val_loss: 2.3024
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step
# Epoch 1/5
# 394/394 - 7s - 17ms/step - accuracy: 0.9951 - loss: 0.0160 - val_accuracy: 0.9950 - val_loss: 0.0175
# Epoch 2/5
# 394/394 - 4s - 11ms/step - accuracy: 0.9976 - loss: 0.0082 - val_accuracy: 0.9945 - val_loss: 0.0194
# Epoch 3/5
# 394/394 - 5s - 12ms/step - accuracy: 0.9980 - loss: 0.0071 - val_accuracy: 0.9952 - val_loss: 0.0192
# Epoch 4/5
# 394/394 - 4s - 11ms/step - accuracy: 0.9981 - loss: 0.0059 - val_accuracy: 0.9941 - val_loss: 0.0201
# Epoch 5/5
# 394/394 - 5s - 12ms/step - accuracy: 0.9981 - loss: 0.0049 - val_accuracy: 0.9964 - val_loss: 0.0192
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
# Epoch 1/5
# 394/394 - 13s - 33ms/step - accuracy: 0.9968 - loss: 0.0118 - val_accuracy: 0.9930 - val_loss: 0.0210
# Epoch 2/5
# 394/394 - 11s - 28ms/step - accuracy: 0.9975 - loss: 0.0079 - val_accuracy: 0.9970 - val_loss: 0.0129
# Epoch 3/5
# 394/394 - 11s - 28ms/step - accuracy: 0.9984 - loss: 0.0052 - val_accuracy: 0.9952 - val_loss: 0.0138
# Epoch 4/5
# 394/394 - 11s - 28ms/step - accuracy: 0.9978 - loss: 0.0065 - val_accuracy: 0.9952 - val_loss: 0.0217
# Epoch 5/5
# 394/394 - 11s - 28ms/step - accuracy: 0.9986 - loss: 0.0049 - val_accuracy: 0.9955 - val_loss: 0.0167
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Epoch 1/5
# 394/394 - 2s - 6ms/step - accuracy: 0.1129 - loss: 2.3012 - val_accuracy: 0.1093 - val_loss: 2.3020
# Epoch 2/5
# 394/394 - 3s - 7ms/step - accuracy: 0.1129 - loss: 2.3012 - val_accuracy: 0.1093 - val_loss: 2.3022
# Epoch 3/5
# 394/394 - 3s - 7ms/step - accuracy: 0.1129 - loss: 2.3012 - val_accuracy: 0.1093 - val_loss: 2.3022
# Epoch 4/5
# 394/394 - 2s - 6ms/step - accuracy: 0.1129 - loss: 2.3011 - val_accuracy: 0.1093 - val_loss: 2.3023
# Epoch 5/5
# 394/394 - 2s - 6ms/step - accuracy: 0.1129 - loss: 2.3012 - val_accuracy: 0.1093 - val_loss: 2.3023
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
cifar_models=[
    ("CNN", build_cnn((32,32,3),10)),
    ("VGG16", build_vgg16((32,32,3),10)),
    ("AlexNet", build_alexnet_small((32,32,3),10)),
    ("GoogLeNet", build_googlenet_small((32,32,3),10)),
    ("RNN", build_rnn((32,32*3),10))
]

for split in splits:
    X_train, X_test, y_train, y_test = train_test_split(c_x_all, c_y_all, train_size=split, random_state=42, stratify=c_y_all)
    X_train_cat, X_test_cat = to_categorical(y_train,10), to_categorical(y_test,10)

    for name, model in cifar_models:
        if name=="RNN":
            X_train_rnn = X_train.reshape(-1,32,32*3)
            X_test_rnn = X_test.reshape(-1,32,32*3)
            res=train_and_eval(model,X_train_rnn,X_train_cat,X_test_rnn,y_test,X_test_cat,name,"CIFAR10",split)
        else:
            res=train_and_eval(model,X_train,X_train_cat,X_test,y_test,X_test_cat,name,"CIFAR10",split)
        results.append(res)
# Out:
# Epoch 1/5
# 254/254 - 8s - 30ms/step - accuracy: 0.4240 - loss: 1.5952 - val_accuracy: 0.5108 - val_loss: 1.3663
# Epoch 2/5
# 254/254 - 2s - 9ms/step - accuracy: 0.5768 - loss: 1.1981 - val_accuracy: 0.5628 - val_loss: 1.2174
# Epoch 3/5
# 254/254 - 2s - 8ms/step - accuracy: 0.6413 - loss: 1.0238 - val_accuracy: 0.6450 - val_loss: 1.0091
# Epoch 4/5
# 254/254 - 2s - 9ms/step - accuracy: 0.6902 - loss: 0.8847 - val_accuracy: 0.6742 - val_loss: 0.9310
# Epoch 5/5
# 254/254 - 2s - 8ms/step - accuracy: 0.7213 - loss: 0.7971 - val_accuracy: 0.6833 - val_loss: 0.9150
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# Epoch 1/5
# 254/254 - 32s - 126ms/step - accuracy: 0.0993 - loss: 2.3044 - val_accuracy: 0.0994 - val_loss: 2.3026
# Epoch 2/5
# 254/254 - 19s - 75ms/step - accuracy: 0.0963 - loss: 2.3027 - val_accuracy: 0.0964 - val_loss: 2.3027
# Epoch 3/5
# 254/254 - 19s - 74ms/step - accuracy: 0.0991 - loss: 2.3027 - val_accuracy: 0.0975 - val_loss: 2.3027
# Epoch 4/5
# 254/254 - 19s - 74ms/step - accuracy: 0.0977 - loss: 2.3027 - val_accuracy: 0.0975 - val_loss: 2.3027
# Epoch 5/5
# 254/254 - 19s - 74ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.0922 - val_loss: 2.3028
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step
# Epoch 1/5
# 254/254 - 9s - 34ms/step - accuracy: 0.4414 - loss: 1.5489 - val_accuracy: 0.5731 - val_loss: 1.2101
# Epoch 2/5
# 254/254 - 3s - 12ms/step - accuracy: 0.6150 - loss: 1.0903 - val_accuracy: 0.6258 - val_loss: 1.0696
# Epoch 3/5
# 254/254 - 3s - 12ms/step - accuracy: 0.6898 - loss: 0.8881 - val_accuracy: 0.6806 - val_loss: 0.9269
# Epoch 4/5
# 254/254 - 3s - 12ms/step - accuracy: 0.7366 - loss: 0.7487 - val_accuracy: 0.6922 - val_loss: 0.9108
# Epoch 5/5
# 254/254 - 3s - 12ms/step - accuracy: 0.7828 - loss: 0.6185 - val_accuracy: 0.7147 - val_loss: 0.8572
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# Epoch 1/5
# 254/254 - 12s - 49ms/step - accuracy: 0.4280 - loss: 1.5751 - val_accuracy: 0.5653 - val_loss: 1.2360
# Epoch 2/5
# 254/254 - 7s - 29ms/step - accuracy: 0.6337 - loss: 1.0463 - val_accuracy: 0.6308 - val_loss: 1.0506
# Epoch 3/5
# 254/254 - 7s - 29ms/step - accuracy: 0.7132 - loss: 0.8190 - val_accuracy: 0.7122 - val_loss: 0.8445
# Epoch 4/5
# 254/254 - 7s - 29ms/step - accuracy: 0.7725 - loss: 0.6513 - val_accuracy: 0.7153 - val_loss: 0.8266
# Epoch 5/5
# 254/254 - 7s - 29ms/step - accuracy: 0.8233 - loss: 0.4997 - val_accuracy: 0.7256 - val_loss: 0.8597
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# Epoch 1/5
# 254/254 - 3s - 13ms/step - accuracy: 0.3127 - loss: 1.8841 - val_accuracy: 0.3572 - val_loss: 1.7490
# Epoch 2/5
# 254/254 - 2s - 7ms/step - accuracy: 0.4074 - loss: 1.6361 - val_accuracy: 0.4228 - val_loss: 1.5954
# Epoch 3/5
# 254/254 - 2s - 9ms/step - accuracy: 0.4433 - loss: 1.5410 - val_accuracy: 0.4439 - val_loss: 1.5472
# Epoch 4/5
# 254/254 - 2s - 7ms/step - accuracy: 0.4713 - loss: 1.4608 - val_accuracy: 0.4739 - val_loss: 1.4744
# Epoch 5/5
# 254/254 - 2s - 6ms/step - accuracy: 0.4944 - loss: 1.4012 - val_accuracy: 0.4658 - val_loss: 1.5168
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# Epoch 1/5
# 296/296 - 4s - 14ms/step - accuracy: 0.7371 - loss: 0.7585 - val_accuracy: 0.7305 - val_loss: 0.7816
# Epoch 2/5
# 296/296 - 2s - 8ms/step - accuracy: 0.7663 - loss: 0.6741 - val_accuracy: 0.7479 - val_loss: 0.7499
# Epoch 3/5
# 296/296 - 2s - 8ms/step - accuracy: 0.7927 - loss: 0.5971 - val_accuracy: 0.7364 - val_loss: 0.7633
# Epoch 4/5
# 296/296 - 3s - 9ms/step - accuracy: 0.8152 - loss: 0.5313 - val_accuracy: 0.7379 - val_loss: 0.7900
# Epoch 5/5
# 296/296 - 2s - 8ms/step - accuracy: 0.8407 - loss: 0.4572 - val_accuracy: 0.7431 - val_loss: 0.8083
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/5
# 296/296 - 26s - 88ms/step - accuracy: 0.0991 - loss: 2.3027 - val_accuracy: 0.0888 - val_loss: 2.3029
# Epoch 2/5
# 296/296 - 22s - 74ms/step - accuracy: 0.0992 - loss: 2.3027 - val_accuracy: 0.0888 - val_loss: 2.3032
# Epoch 3/5
# 296/296 - 22s - 74ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.0888 - val_loss: 2.3031
# Epoch 4/5
# 296/296 - 22s - 73ms/step - accuracy: 0.1013 - loss: 2.3027 - val_accuracy: 0.0931 - val_loss: 2.3030
# Epoch 5/5
# 296/296 - 22s - 74ms/step - accuracy: 0.0999 - loss: 2.3027 - val_accuracy: 0.0888 - val_loss: 2.3030
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
# Epoch 1/5
# 296/296 - 5s - 18ms/step - accuracy: 0.8013 - loss: 0.5794 - val_accuracy: 0.7798 - val_loss: 0.6376
# Epoch 2/5
# 296/296 - 3s - 12ms/step - accuracy: 0.8430 - loss: 0.4572 - val_accuracy: 0.8076 - val_loss: 0.5711
# Epoch 3/5
# 296/296 - 4s - 12ms/step - accuracy: 0.8762 - loss: 0.3566 - val_accuracy: 0.7957 - val_loss: 0.6686
# Epoch 4/5
# 296/296 - 3s - 12ms/step - accuracy: 0.9124 - loss: 0.2553 - val_accuracy: 0.7931 - val_loss: 0.6657
# Epoch 5/5
# 296/296 - 3s - 12ms/step - accuracy: 0.9451 - loss: 0.1650 - val_accuracy: 0.7960 - val_loss: 0.7415
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# Epoch 1/5
# 296/296 - 11s - 36ms/step - accuracy: 0.8440 - loss: 0.4695 - val_accuracy: 0.8317 - val_loss: 0.4913
# Epoch 2/5
# 296/296 - 8s - 28ms/step - accuracy: 0.8944 - loss: 0.3073 - val_accuracy: 0.8293 - val_loss: 0.5308
# Epoch 3/5
# 296/296 - 8s - 29ms/step - accuracy: 0.9428 - loss: 0.1692 - val_accuracy: 0.8202 - val_loss: 0.5860
# Epoch 4/5
# 296/296 - 8s - 29ms/step - accuracy: 0.9670 - loss: 0.0998 - val_accuracy: 0.8019 - val_loss: 0.7530
# Epoch 5/5
# 296/296 - 8s - 28ms/step - accuracy: 0.9800 - loss: 0.0626 - val_accuracy: 0.8193 - val_loss: 0.7574
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# Epoch 1/5
# 296/296 - 2s - 7ms/step - accuracy: 0.5061 - loss: 1.3726 - val_accuracy: 0.5164 - val_loss: 1.3709
# Epoch 2/5
# 296/296 - 2s - 6ms/step - accuracy: 0.5273 - loss: 1.3161 - val_accuracy: 0.5362 - val_loss: 1.3138
# Epoch 3/5
# 296/296 - 2s - 7ms/step - accuracy: 0.5436 - loss: 1.2779 - val_accuracy: 0.5331 - val_loss: 1.2984
# Epoch 4/5
# 296/296 - 2s - 8ms/step - accuracy: 0.5588 - loss: 1.2341 - val_accuracy: 0.5490 - val_loss: 1.2776
# Epoch 5/5
# 296/296 - 2s - 6ms/step - accuracy: 0.5678 - loss: 1.2001 - val_accuracy: 0.5467 - val_loss: 1.2790
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/5
# 338/338 - 5s - 14ms/step - accuracy: 0.8304 - loss: 0.5021 - val_accuracy: 0.8173 - val_loss: 0.5387
# Epoch 2/5
# 338/338 - 3s - 8ms/step - accuracy: 0.8574 - loss: 0.4212 - val_accuracy: 0.8067 - val_loss: 0.5742
# Epoch 3/5
# 338/338 - 3s - 8ms/step - accuracy: 0.8785 - loss: 0.3557 - val_accuracy: 0.7962 - val_loss: 0.6370
# Epoch 4/5
# 338/338 - 3s - 8ms/step - accuracy: 0.8984 - loss: 0.2939 - val_accuracy: 0.7775 - val_loss: 0.7042
# Epoch 5/5
# 338/338 - 3s - 9ms/step - accuracy: 0.9162 - loss: 0.2405 - val_accuracy: 0.7890 - val_loss: 0.7135
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/5
# 338/338 - 29s - 86ms/step - accuracy: 0.0994 - loss: 2.3027 - val_accuracy: 0.0944 - val_loss: 2.3028
# Epoch 2/5
# 338/338 - 25s - 74ms/step - accuracy: 0.0995 - loss: 2.3027 - val_accuracy: 0.0904 - val_loss: 2.3029
# Epoch 3/5
# 338/338 - 25s - 74ms/step - accuracy: 0.1008 - loss: 2.3027 - val_accuracy: 0.0944 - val_loss: 2.3029
# Epoch 4/5
# 338/338 - 25s - 74ms/step - accuracy: 0.1001 - loss: 2.3027 - val_accuracy: 0.0904 - val_loss: 2.3029
# Epoch 5/5
# 338/338 - 25s - 74ms/step - accuracy: 0.0977 - loss: 2.3027 - val_accuracy: 0.0904 - val_loss: 2.3028
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
# Epoch 1/5
# 338/338 - 6s - 18ms/step - accuracy: 0.9063 - loss: 0.3073 - val_accuracy: 0.8900 - val_loss: 0.3596
# Epoch 2/5
# 338/338 - 4s - 12ms/step - accuracy: 0.9400 - loss: 0.1824 - val_accuracy: 0.8921 - val_loss: 0.3753
# Epoch 3/5
# 338/338 - 4s - 12ms/step - accuracy: 0.9607 - loss: 0.1212 - val_accuracy: 0.8819 - val_loss: 0.4382
# Epoch 4/5
# 338/338 - 4s - 12ms/step - accuracy: 0.9720 - loss: 0.0848 - val_accuracy: 0.8752 - val_loss: 0.4782
# Epoch 5/5
# 338/338 - 4s - 12ms/step - accuracy: 0.9776 - loss: 0.0669 - val_accuracy: 0.8733 - val_loss: 0.5383
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/5
# 338/338 - 11s - 34ms/step - accuracy: 0.9242 - loss: 0.2680 - val_accuracy: 0.9181 - val_loss: 0.2894
# Epoch 2/5
# 338/338 - 10s - 28ms/step - accuracy: 0.9712 - loss: 0.0938 - val_accuracy: 0.9092 - val_loss: 0.3573
# Epoch 3/5
# 338/338 - 10s - 29ms/step - accuracy: 0.9851 - loss: 0.0461 - val_accuracy: 0.8885 - val_loss: 0.5163
# Epoch 4/5
# 338/338 - 10s - 29ms/step - accuracy: 0.9855 - loss: 0.0444 - val_accuracy: 0.9019 - val_loss: 0.4254
# Epoch 5/5
# 338/338 - 10s - 29ms/step - accuracy: 0.9873 - loss: 0.0379 - val_accuracy: 0.8852 - val_loss: 0.5439
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Epoch 1/5
# 338/338 - 2s - 7ms/step - accuracy: 0.5720 - loss: 1.1969 - val_accuracy: 0.5615 - val_loss: 1.2112
# Epoch 2/5
# 338/338 - 2s - 6ms/step - accuracy: 0.5880 - loss: 1.1516 - val_accuracy: 0.5760 - val_loss: 1.1817
# Epoch 3/5
# 338/338 - 3s - 8ms/step - accuracy: 0.5995 - loss: 1.1254 - val_accuracy: 0.5702 - val_loss: 1.1961
# Epoch 4/5
# 338/338 - 2s - 6ms/step - accuracy: 0.6114 - loss: 1.0900 - val_accuracy: 0.5740 - val_loss: 1.1739
# Epoch 5/5
# 338/338 - 2s - 7ms/step - accuracy: 0.6243 - loss: 1.0578 - val_accuracy: 0.5823 - val_loss: 1.1933
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
df=pd.DataFrame(results)
print("\n=== Final Deep Learning Comparison Table (Multiple Splits) ===")
display(df)
df.to_csv("DeepLearning_Comparison_MultiSplits.csv",index=False)
print("Saved DeepLearning_Comparison_MultiSplits.csv ✅")
# Out:
# === Final Deep Learning Comparison Table (Multiple Splits) ===
#     Dataset      Model  Split  Accuracy  Precision    Recall        F1  \
# 0     MNIST        CNN    0.6  0.985714   0.985805  0.985714  0.985707
# 1     MNIST      VGG16    0.6  0.112536   0.012664  0.112536  0.022767
# 2     MNIST    AlexNet    0.6  0.989429   0.989466  0.989429  0.989430
# 3     MNIST  GoogLeNet    0.6  0.989357   0.989387  0.989357  0.989354
# 4     MNIST        RNN    0.6  0.112536   0.012664  0.112536  0.022767
# 5     MNIST        CNN    0.7  0.989762   0.989800  0.989762  0.989767
# 6     MNIST      VGG16    0.7  0.112524   0.012662  0.112524  0.022762
# 7     MNIST    AlexNet    0.7  0.991667   0.991706  0.991667  0.991671
# 8     MNIST  GoogLeNet    0.7  0.991286   0.991296  0.991286  0.991286
# 9     MNIST        RNN    0.7  0.112524   0.012662  0.112524  0.022762
# 10    MNIST        CNN    0.8  0.988857   0.988973  0.988857  0.988865
# 11    MNIST      VGG16    0.8  0.112500   0.012656  0.112500  0.022753
# 12    MNIST    AlexNet    0.8  0.992286   0.992312  0.992286  0.992290
# 13    MNIST  GoogLeNet    0.8  0.990786   0.990807  0.990786  0.990789
# 14    MNIST        RNN    0.8  0.112500   0.012656  0.112500  0.022753
# 15  CIFAR10        CNN    0.6  0.678792   0.690115  0.678792  0.676356
# 16  CIFAR10      VGG16    0.6  0.100000   0.010000  0.100000  0.018182
# 17  CIFAR10    AlexNet    0.6  0.714375   0.730193  0.714375  0.714189
# 18  CIFAR10  GoogLeNet    0.6  0.717958   0.722333  0.717958  0.716353
# 19  CIFAR10        RNN    0.6  0.467125   0.487181  0.467125  0.470488
# 20  CIFAR10        CNN    0.7  0.708944   0.721869  0.708944  0.710399
# 21  CIFAR10      VGG16    0.7  0.100000   0.010000  0.100000  0.018182
# 22  CIFAR10    AlexNet    0.7  0.747444   0.749141  0.747444  0.745639
# 23  CIFAR10  GoogLeNet    0.7  0.735778   0.737554  0.735778  0.734153
# 24  CIFAR10        RNN    0.7  0.537333   0.548021  0.537333  0.536707
# 25  CIFAR10        CNN    0.8  0.722583   0.727497  0.722583  0.724056
# 26  CIFAR10      VGG16    0.8  0.100000   0.010000  0.100000  0.018182
# 27  CIFAR10    AlexNet    0.8  0.750000   0.760849  0.750000  0.752102
# 28  CIFAR10  GoogLeNet    0.8  0.740333   0.738670  0.740333  0.738553
# 29  CIFAR10        RNN    0.8  0.551333   0.550117  0.551333  0.545164
#
#          AUC                                            History  \
# 0   0.999811  <keras.src.callbacks.history.History object at...
# 1   0.500000  <keras.src.callbacks.history.History object at...
# 2   0.999887  <keras.src.callbacks.history.History object at...
# 3   0.999874  <keras.src.callbacks.history.History object at...
# 4   0.500034  <keras.src.callbacks.history.History object at...
# 5   0.999881  <keras.src.callbacks.history.History object at...
# 6   0.500000  <keras.src.callbacks.history.History object at...
# 7   0.999907  <keras.src.callbacks.history.History object at...
# 8   0.999885  <keras.src.callbacks.history.History object at...
# 9   0.500047  <keras.src.callbacks.history.History object at...
# 10  0.999932  <keras.src.callbacks.history.History object at...
# 11  0.500000  <keras.src.callbacks.history.History object at...
# 12  0.999950  <keras.src.callbacks.history.History object at...
# 13  0.999939  <keras.src.callbacks.history.History object at...
# 14  0.500000  <keras.src.callbacks.history.History object at...
# 15  0.951164  <keras.src.callbacks.history.History object at...
# 16  0.500000  <keras.src.callbacks.history.History object at...
# 17  0.960303  <keras.src.callbacks.history.History object at...
# 18  0.959413  <keras.src.callbacks.history.History object at...
# 19  0.870730  <keras.src.callbacks.history.History object at...
# 20  0.958088  <keras.src.callbacks.history.History object at...
# 21  0.500000  <keras.src.callbacks.history.History object at...
# 22  0.965499  <keras.src.callbacks.history.History object at...
# 23  0.961269  <keras.src.callbacks.history.History object at...
# 24  0.902654  <keras.src.callbacks.history.History object at...
# 25  0.958407  <keras.src.callbacks.history.History object at...
# 26  0.500000  <keras.src.callbacks.history.History object at...
# 27  0.965444  <keras.src.callbacks.history.History object at...
# 28  0.962478  <keras.src.callbacks.history.History object at...
# 29  0.908787  <keras.src.callbacks.history.History object at...
#
#                                                Y_true  \
# 0   [7, 6, 6, 9, 0, 6, 6, 1, 4, 0, 6, 4, 1, 4, 3, ...
# 1   [7, 6, 6, 9, 0, 6, 6, 1, 4, 0, 6, 4, 1, 4, 3, ...
# 2   [7, 6, 6, 9, 0, 6, 6, 1, 4, 0, 6, 4, 1, 4, 3, ...
# 3   [7, 6, 6, 9, 0, 6, 6, 1, 4, 0, 6, 4, 1, 4, 3, ...
# 4   [7, 6, 6, 9, 0, 6, 6, 1, 4, 0, 6, 4, 1, 4, 3, ...
# 5   [7, 8, 2, 2, 3, 9, 2, 1, 6, 5, 9, 5, 8, 9, 8, ...
# 6   [7, 8, 2, 2, 3, 9, 2, 1, 6, 5, 9, 5, 8, 9, 8, ...
# 7   [7, 8, 2, 2, 3, 9, 2, 1, 6, 5, 9, 5, 8, 9, 8, ...
# 8   [7, 8, 2, 2, 3, 9, 2, 1, 6, 5, 9, 5, 8, 9, 8, ...
# 9   [7, 8, 2, 2, 3, 9, 2, 1, 6, 5, 9, 5, 8, 9, 8, ...
# 10  [7, 3, 1, 1, 2, 5, 9, 8, 8, 1, 6, 6, 3, 6, 8, ...
# 11  [7, 3, 1, 1, 2, 5, 9, 8, 8, 1, 6, 6, 3, 6, 8, ...
# 12  [7, 3, 1, 1, 2, 5, 9, 8, 8, 1, 6, 6, 3, 6, 8, ...
# 13  [7, 3, 1, 1, 2, 5, 9, 8, 8, 1, 6, 6, 3, 6, 8, ...
# 14  [7, 3, 1, 1, 2, 5, 9, 8, 8, 1, 6, 6, 3, 6, 8, ...
# 15  [7, 8, 6, 2, 5, 7, 3, 2, 4, 6, 8, 1, 9, 7, 9, ...
# 16  [7, 8, 6, 2, 5, 7, 3, 2, 4, 6, 8, 1, 9, 7, 9, ...
# 17  [7, 8, 6, 2, 5, 7, 3, 2, 4, 6, 8, 1, 9, 7, 9, ...
# 18  [7, 8, 6, 2, 5, 7, 3, 2, 4, 6, 8, 1, 9, 7, 9, ...
# 19  [7, 8, 6, 2, 5, 7, 3, 2, 4, 6, 8, 1, 9, 7, 9, ...
# 20  [7, 1, 5, 3, 1, 4, 3, 5, 3, 9, 0, 3, 0, 9, 4, ...
# 21  [7, 1, 5, 3, 1, 4, 3, 5, 3, 9, 0, 3, 0, 9, 4, ...
# 22  [7, 1, 5, 3, 1, 4, 3, 5, 3, 9, 0, 3, 0, 9, 4, ...
# 23  [7, 1, 5, 3, 1, 4, 3, 5, 3, 9, 0, 3, 0, 9, 4, ...
# 24  [7, 1, 5, 3, 1, 4, 3, 5, 3, 9, 0, 3, 0, 9, 4, ...
# 25  [5, 4, 5, 2, 1, 5, 0, 1, 2, 0, 2, 5, 3, 6, 0, ...
# 26  [5, 4, 5, 2, 1, 5, 0, 1, 2, 0, 2, 5, 3, 6, 0, ...
# 27  [5, 4, 5, 2, 1, 5, 0, 1, 2, 0, 2, 5, 3, 6, 0, ...
# 28  [5, 4, 5, 2, 1, 5, 0, 1, 2, 0, 2, 5, 3, 6, 0, ...
# 29  [5, 4, 5, 2, 1, 5, 0, 1, 2, 0, 2, 5, 3, 6, 0, ...
#
#                                                Y_pred
# 0   [[3.2954839e-09, 1.4691416e-09, 2.9017729e-08,...
# 1   [[0.09803039, 0.114775084, 0.10115121, 0.10106...
# 2   [[5.3195848e-09, 1.0978426e-12, 1.0274163e-09,...
# 3   [[1.7951739e-10, 3.5541407e-11, 1.3732905e-07,...
# 4   [[0.09976294, 0.111437425, 0.1014404, 0.100026...
# 5   [[2.1947021e-20, 5.0551286e-15, 1.8491397e-13,...
# 6   [[0.09867746, 0.112955965, 0.1003747, 0.100876...
# 7   [[6.7273176e-17, 1.46834e-11, 6.916122e-11, 3....
# 8   [[1.3981436e-12, 6.537398e-10, 9.881334e-11, 1...
# 9   [[0.100039616, 0.11347015, 0.10065162, 0.10128...
# 10  [[1.5410083e-09, 1.3085815e-11, 3.7970148e-11,...
# 11  [[0.09722452, 0.114170514, 0.09924617, 0.10298...
# 12  [[1.32380535e-14, 9.018309e-15, 5.575361e-15, ...
# 13  [[1.3478629e-20, 3.764104e-19, 1.5519136e-20, ...
# 14  [[0.09952406, 0.113287345, 0.09947171, 0.10156...
# 15  [[8.8408226e-05, 8.9013025e-05, 0.00073544733,...
# 16  [[0.09912781, 0.09974446, 0.10039917, 0.100576...
# 17  [[0.0011662842, 8.682385e-05, 0.0025468522, 0....
# 18  [[5.4141765e-05, 1.0828e-05, 0.0014648121, 0.0...
# 19  [[0.029835282, 0.024764387, 0.12076233, 0.1694...
# 20  [[3.3875724e-05, 6.6417914e-07, 0.8050009, 0.0...
# 21  [[0.099252656, 0.10040357, 0.09943949, 0.10125...
# 22  [[3.7890954e-05, 3.189004e-07, 0.17778759, 0.0...
# 23  [[1.8275168e-05, 8.351272e-09, 0.62016314, 0.0...
# 24  [[0.022729691, 0.0021332516, 0.3172323, 0.1038...
# 25  [[2.2646602e-06, 1.4091902e-05, 2.7565088e-07,...
# 26  [[0.09927151, 0.10052306, 0.099333875, 0.09996...
# 27  [[1.4458772e-12, 1.0947309e-08, 4.36837e-14, 0...
# 28  [[6.1298975e-09, 3.6684995e-09, 5.0542972e-08,...
# 29  [[0.15287472, 0.0023521208, 0.037769545, 0.447...
# Saved DeepLearning_Comparison_MultiSplits.csv ✅

# %%
best_cases = df.loc[df.groupby(['Dataset','Model'])['Accuracy'].idxmax()]

# %%
for idx, row in best_cases.iterrows():
    hist = row['History']
    y_true = row['Y_true']
    y_pred = row['Y_pred']
    plot_history(hist,f"{row['Dataset']} {row['Model']} best split={row['Split']}")
    pred_labels = np.argmax(y_pred,axis=1)
    plot_cm(y_true,pred_labels,f"{row['Dataset']} {row['Model']} best split={row['Split']}")
    plot_roc(to_categorical(y_true,10), y_pred, f"{row['Dataset']} {row['Model']} best split={row['Split']}")

# %%
best_cases.drop(columns=['History','Y_true','Y_pred'], inplace=True)
best_cases.to_csv("DeepLearning_BestCase_Comparison.csv",index=False)
print("Saved DeepLearning_BestCase_Comparison.csv ✅")
display(best_cases)
# Out:
# Saved DeepLearning_BestCase_Comparison.csv ✅
#     Dataset      Model  Split  Accuracy  Precision    Recall        F1  \
# 27  CIFAR10    AlexNet    0.8  0.750000   0.760849  0.750000  0.752102
# 25  CIFAR10        CNN    0.8  0.722583   0.727497  0.722583  0.724056
# 28  CIFAR10  GoogLeNet    0.8  0.740333   0.738670  0.740333  0.738553
# 29  CIFAR10        RNN    0.8  0.551333   0.550117  0.551333  0.545164
# 16  CIFAR10      VGG16    0.6  0.100000   0.010000  0.100000  0.018182
# 12    MNIST    AlexNet    0.8  0.992286   0.992312  0.992286  0.992290
# 5     MNIST        CNN    0.7  0.989762   0.989800  0.989762  0.989767
# 8     MNIST  GoogLeNet    0.7  0.991286   0.991296  0.991286  0.991286
# 4     MNIST        RNN    0.6  0.112536   0.012664  0.112536  0.022767
# 1     MNIST      VGG16    0.6  0.112536   0.012664  0.112536  0.022767
#
#          AUC
# 27  0.965444
# 25  0.958407
# 28  0.962478
# 29  0.908787
# 16  0.500000
# 12  0.999950
# 5   0.999881
# 8   0.999885
# 4   0.500034
# 1   0.500000
